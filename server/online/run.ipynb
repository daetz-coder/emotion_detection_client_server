# %%
# !python video.py
# Out:
# 2024-10-31 16:23:48.945150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-31 16:23:49.358220: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  * Serving Flask app 'video'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:7777
#  * Running on http://192.168.1.103:7777
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 717-145-627
# 100.68.1.118 - - [31/Oct/2024 16:23:58] "POST /analyze HTTP/1.1" 200 -
# 100.68.1.118 - - [31/Oct/2024 16:23:59] "POST /analyze HTTP/1.1" 200 -
# ...

# %%
# !python video_light.py
# Out:
# 2024-10-31 16:24:58.386504: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-31 16:24:58.792564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  * Serving Flask app 'video_light'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:7777
#  * Running on http://192.168.1.103:7777
# Press CTRL+C to quit
# ...
